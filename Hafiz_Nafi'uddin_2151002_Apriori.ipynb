# %%
pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=58484b4abb432c1a97a67c82ebbe5ce12db3b11f4e08996bd2f9163b0fb7bc08
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %%
google_sheets_link = "https://raw.githubusercontent.com/HafizAlHazfu/Apriori/main/new%20data.xls%20-%20data1.csv"

data_store = pd.read_csv(google_sheets_link)
data_store.tail()
# Out:
#     Barang 1 Barang 2 Barang 3 Barang 4 Barang 5 Barang 6
# 96      Wine    Chips    Bread   Butter      NaN    Apple
# 97      Wine    Chips    Bread      NaN      NaN      NaN
# 98      Wine    Chips    Bread   Butter      NaN    Apple
# 99      Wine    Chips    Bread      NaN      NaN      NaN
# 100     Wine    Chips    Bread   Butter      NaN    Apple

# %%
data_store.shape
# Out:
# (101, 6)

# %%
records = []
for i in range(0, 51):
    records.append([str(data_store.values[i,j]) for j in range(0,6)])

# %%
association_rules = apriori(records, min_support=0.10, min_confidence=0.7, min_lift=1.2, main_lenght=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 15

# %%
print(len(association_results[0]))
# Out:
# 3

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'Bread', 'Wine', 'Apple'}), support=0.5882352941176471, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread'}), items_add=frozenset({'Wine', 'Apple'}), confidence=0.75, lift=1.2338709677419355), OrderedStatistic(items_base=frozenset({'Wine', 'Apple'}), items_add=frozenset({'Bread'}), confidence=0.9677419354838711, lift=1.2338709677419357)])

# %%
results =[]
for item in association_results:
    pair = item[0]
    items = [x for x in pair]

    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]
    value3 = str(item[2][0][2])[:6]
    value4 = str(item[2][0][3])[:6]

    rows = (value0,value1,value2,value3,value4)

    results.append(rows)

    label = ['title1', 'title2','support','confidence','lift']

    store_suggestion = pd.DataFrame(results, columns=label)

    print(store_suggestion)
# Out:
#   title1 title2 support confidence    lift
# 0  Bread   Wine  0.5882       0.75  1.2338
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
# 3  Bread    Wine  0.3529        1.0   1.275
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
# 3  Bread    Wine  0.3529        1.0   1.275
    pair = item[0]
    items = [x for x in pair]

    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]
    value3 = str(item[2][0][2])[:6]
    value4 = str(item[2][0][3])[:6]

    rows = (value0,value1,value2,value3,value4)

    results.append(rows)

    label = ['title1', 'title2','support','confidence','lift']

    store_suggestion = pd.DataFrame(results, columns=label)

    print(store_suggestion)
# Out:
#   title1 title2 support confidence    lift
# 0  Bread   Wine  0.5882       0.75  1.2338
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
# 3  Bread    Wine  0.3529        1.0   1.275
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
# 3  Bread    Wine  0.3529        1.0   1.275
# 4  Bread    Wine  0.5490     0.7000  1.2310
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
# 3  Bread    Wine  0.3529        1.0   1.275
# 4  Bread    Wine  0.5490     0.7000  1.2310
# 5  Bread    Wine  0.3529     0.9473  1.2078
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
# 3  Bread    Wine  0.3529        1.0   1.275
# 4  Bread    Wine  0.5490     0.7000  1.2310
# 5  Bread    Wine  0.3529     0.9473  1.2078
# 6  Bread  Butter  0.2941        1.0   1.275
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
# 3  Bread    Wine  0.3529        1.0   1.275
# 4  Bread    Wine  0.5490     0.7000  1.2310
# 5  Bread    Wine  0.3529     0.9473  1.2078
# 6  Bread  Butter  0.2941        1.0   1.275
# 7  Bread  Butter  0.4901     0.9259  1.2762
#   title1  title2 support confidence    lift
# 0  Bread    Wine  0.5882       0.75  1.2338
# 1  Bread  Butter  0.5098     0.9629  1.2277
# 2  Bread  Butter  0.4509     0.8518  1.2067
# 3  Bread    Wine  0.3529        1.0   1.275
# 4  Bread    Wine  0.5490     0.7000  1.2310
# 5  Bread    Wine  0.3529     0.9473  1.2078
# 6  Bread  Butter  0.2941        1.0   1.275
# 5   Bread    Wine  0.3529     0.9473  1.2078
# 6   Bread  Butter  0.2941        1.0   1.275
# 7   Bread  Butter  0.4901     0.9259  1.2762
# 8   Bread  Butter  0.2549     0.8666  1.2277
# 9   Bread  Butter  0.4313     0.8148  1.2592
# 10  Bread    Milk  0.3333     0.9444  1.3018
# 11  Bread     nan  0.1176        1.0   1.275
# 12  Bread     nan  0.3137     0.9411     1.2
# 13  Bread  Butter  0.2745     0.9333  1.2864
#    title1  title2 support confidence    lift
# 0   Bread    Wine  0.5882       0.75  1.2338
# 1   Bread  Butter  0.5098     0.9629  1.2277
# 2   Bread  Butter  0.4509     0.8518  1.2067
# 3   Bread    Wine  0.3529        1.0   1.275
# 4   Bread    Wine  0.5490     0.7000  1.2310
# 5   Bread    Wine  0.3529     0.9473  1.2078
# 6   Bread  Butter  0.2941        1.0   1.275
# 7   Bread  Butter  0.4901     0.9259  1.2762
# 8   Bread  Butter  0.2549     0.8666  1.2277
# 9   Bread  Butter  0.4313     0.8148  1.2592
# 10  Bread    Milk  0.3333     0.9444  1.3018
# 11  Bread     nan  0.1176        1.0   1.275
# 12  Bread     nan  0.3137     0.9411     1.2
# 13  Bread  Butter  0.2745     0.9333  1.2864
# 14  Bread  Butter  0.2352     0.7999  1.2363

# %%
results = []
for item in association_results:
    pair = item[0]
    items = [x for x in pair]

    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]  # Potong value2 menjadi 6 karakter pertama (opsional)
    value3 = str(item[2][0][2])[:6]  # Potong value3 menjadi 6 karakter pertama (opsional)
    value4 = str(item[2][0][3])[:6]  # Potong value4 menjadi 6 karakter pertama (opsional)

    rows = (value0, value1, value2, value3, value4)
    results.append(rows)

label = ['title1', 'title2', 'support', 'confidence', 'lift']

store_suggestion = pd.DataFrame(results, columns=label)  # Gunakan fungsi DataFrame

print(store_suggestion)
# Out:
#    title1  title2 support confidence    lift
# 0   Bread    Wine  0.5882       0.75  1.2338
# 1   Bread  Butter  0.5098     0.9629  1.2277
# 2   Bread  Butter  0.4509     0.8518  1.2067
# 3   Bread    Wine  0.3529        1.0   1.275
# 4   Bread    Wine  0.5490     0.7000  1.2310
# 5   Bread    Wine  0.3529     0.9473  1.2078
# 6   Bread  Butter  0.2941        1.0   1.275
# 7   Bread  Butter  0.4901     0.9259  1.2762
# 8   Bread  Butter  0.2549     0.8666  1.2277
# 9   Bread  Butter  0.4313     0.8148  1.2592
# 10  Bread    Milk  0.3333     0.9444  1.3018
# 11  Bread     nan  0.1176        1.0   1.275
# 12  Bread     nan  0.3137     0.9411     1.2
# 13  Bread  Butter  0.2745     0.9333  1.2864
# 14  Bread  Butter  0.2352     0.7999  1.2363

# %%
store_suggestion.describe()
# Out:
#        title1  title2 support confidence   lift
# count      15      15      15         15     15
# unique      1       4      14         13     12
# top     Bread  Butter  0.3529        1.0  1.275
# freq       15       8       2          3      3

# %%
store_suggestion.to_excel('data_output7.xlsx')
